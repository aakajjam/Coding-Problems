# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
movieFile = pd.read_csv('movies.csv')

# %%
movieFile
# Out:
#        N  Participant  Rank                          MovieTitle ReleaseDate  \
# 0      0            1     1                    The Big Lebowski    3/6/1998
# 1      1            1     2                 Lost In Translation   10/3/2003
# 2      2            1     3  Star Wars: Episode IV - A New Hope   5/25/1977
# 3      3            1     4           O Brother Where Art Thou?  12/22/2000
# 4      4            1     5                        Blade Runner   6/25/1982
# ..   ...          ...   ...                                 ...         ...
# 115  115           12     6                  Olympus Has Fallen   3/18/2013
# 116  116           12     7                           Searching   8/31/2018
# 117  117           12     8                           Inception   7/13/2010
# 118  118           12     9                       Black Panther   2/16/2018
# 119  119           12    10                        Transformers    7/3/2007
#
#       Production Company           Director Rating      Genre  Runtime  \
# 0               Polygram          Joel Coen      R     Comedy      117
# 1         Focus Features      Sofia Coppola      R      Drama      102
# 2              Lucasfilm       George Lucas     PG  Adventure      121
# 3    Touchstone Pictures          Joel Coen  PG-13     Comedy      107
# 4           Warner Bros.       Ridley Scott      R    Mystery      117
# ..                   ...                ...    ...        ...      ...
# 115      Millenium Media      Antoine Fuqua      R     Action      120
# 116     Bazelevs Company    Aneesh Chaganty  PG-13    Mystery      102
# 117         Warner Bros.  Christopher Nolan  PG-13     Sci-fi      148
# 118       Marvel Studios       Ryan Coogler  PG-13     Action      135
# 119  DreamWorks Pictures        Michael Bay  PG-13     Action      144
#
#         Budget  GrossSales  NumAcadAwards  Tomatometer   Budget_2022  \
# 0     15000000    18254458              0           83  2.671487e+07
# 1      4000000    44585453              1           95  6.312655e+06
# 2     11000000   460998507              6           93  5.269045e+07
# 3     26000000    45512588              0           79  4.383406e+07
# 4     30000000    32914489              0           89  9.025380e+07
# ..         ...         ...            ...          ...           ...
# 115   70000000    98925640              0           50  8.723558e+07
# 116     880000    26020957              0           92  1.017409e+06
# 117  160000000   292587330              4           87  2.130220e+08
# 118  200000000   700426566              3           96  2.312294e+08
# 119  147000000   319246193              0           58  2.058262e+08
#
#        Sales_2022
# 0    3.251103e+07
# 1    7.036315e+07
# 2    2.208202e+09
# 3    7.673083e+07
# 4    9.902192e+07
# ..            ...
# 115  1.232834e+08
# 116  3.008405e+07
# 117  3.895471e+08
# 118  8.097960e+08
# 119  4.470016e+08
#
# [120 rows x 16 columns]

# %%
parameters_dropped = movieFile.drop(['N','Participant','Rank', 'Runtime'], axis = 1)

plt.figure(figsize =(9,6))
sns.boxplot(data = movieFile)
# Out:
# <AxesSubplot:>
